# %% [markdown]
# # List of modules I find useful for work

# %%
# %matplotlib inline
import os, sys, json
import numpy as np
import pandas as pd
import root_numpy as rnp
import matplotlib.pyplot as plt
from collections import OrderedDict as OD
plt.rcParams['font.family']='serif'
plt.rcParams['font.weight']='light'
plt.rcParams['font.size']=14
figsize = (12,6)

# %% [markdown]
# # Reading input files with Pandas
# For ROOT files, you'll need root_numpy, which you can find here: https://github.com/rootpy/root_numpy
#
# You can actually even convert directly to pandas without need for numpy with root_pandas, here: https://github.com/ibab/root_pandas

# %%
def Pandafy(fileName, tree):
    df = pd.DataFrame(rnp.root2array(fileName,tree))
    return df

df = Pandafy('Data/tree.root','Tree')
print "TFile pandafied"
# Out:
# TFile pandafied

# %% [markdown]
# and open many file formats in one line

# %%
df = pd.read_csv('Data/particles.csv')

# %% [markdown]
# # Manipulating data with Pandas
# Pandas is extremely useful for data analysis, if you have 10 minutes, I really suggest taking a look at this very short tutorial: http://pandas.pydata.org/pandas-docs/stable/10min.html
#
# It's definitely worth your time.
#
# There are many useful things you can immediately do with your pandas dataframe, you can quickly check on the fly the content...

# %%
df
# Out:
#         Pdg         Vx         Vy          Vz             Px             Py  \
# 0       211  13.649168  16.326958  559.739990  111911.796875  168217.906250
# 1       211   2.049445  -2.937980  559.739990  -16944.531250   10193.381836
# 2       211   6.673971  37.505409  559.739990   55978.347656  308098.593750
# 3       211  -3.974789   7.071727  559.739990  -53305.992188   91847.179688
# 4       211  25.030167   7.490469  559.739990  128032.609375   41156.992188
# 5       211  -9.853389  -8.400913  559.739990  -65508.683594  -52742.710938
# 6       211  -4.108197  26.083431  559.739990  -93956.281250  284670.406250
# 7       211 -29.328348   1.559040  559.739990  -81383.867188  -49704.992188
# 8       321 -29.691681  -3.923775  559.739990 -187788.500000  -23489.945312
# 9       211 -16.104229  -6.477342  559.739990   -9910.785156   -3662.408447
# 10      211  12.435769 -24.692837  559.739990  141839.312500 -270860.531250
# 11      211  26.304205  14.075175  559.739990  176905.359375   93182.781250
# 12      211  10.577537 -26.334660  559.739990  110409.414062 -271260.562500
# 13      211   3.422769  -8.720152  559.739990    3059.918701  -27732.841797
# 14      211 -17.319418  -5.784741  559.739990  -35310.488281   -8764.414062
# 15      211  -0.733737  -2.579229  559.739990    6083.671875  -38770.625000
# 16      321  14.701634   2.578375  559.739990   54165.531250   10266.687500
# 17      211  -9.635771  -9.348013  559.739990  -82452.679688  -73510.359375
# 18      211  10.301291 -28.673756  559.739990   67282.554688 -182095.703125
# 19      211 -14.006187 -17.686737  559.739990  -24349.644531  -34269.355469
# 20      211 -28.023855  13.704400  559.739990 -151179.656250   71232.804688
# 21      211  -1.199552 -16.865175  559.739990   12384.289062  -71784.382812
# 22      211   2.539267   2.916222  559.739990   30481.919922   31327.523438
# 23      211  10.054432   9.221920  559.739990   75401.679688   70078.296875
# 24      321   3.334203   2.143575  559.739990     327.130798    6283.843750
# 25      211  -7.102637 -34.855045  559.739990  310359.968750  -86894.164062
# 23      4.236878e+06
# 24      3.401914e+06
# 25      1.651660e+06
# 26      2.160476e+06
# 27      3.647964e+06
# 28      2.745807e+06
# 29      3.847613e+06
# ...              ...
# 131903  3.157412e+06
# 131904  4.613932e+06
# 131905  3.379586e+06
# 131906 -3.707558e+05
# 131907  4.684140e+06
# 131908  1.941901e+06
# 131909  4.573214e+06
# 131910  5.084600e+06
# 131911  4.566701e+06
# 131912  2.683682e+06
# 131913  3.617230e+06
# 131914  2.045311e+06
# 131915  5.615404e+06
# 131916  7.219996e+06
# 131917  5.242094e+06
# 131918  2.611370e+06
# 131919  2.207729e+06
# 131920  4.347429e+05
# 131921  6.208270e+06
# 131922  3.702776e+06
# 131923  6.632431e+06
# 131924  1.626301e+06
# 131925  6.920352e+06
# 131926  1.135009e+06
# 131927  4.023198e+06
# 131928  3.047436e+06
# 131929  1.351753e+06
# 131930  3.852642e+06
# 131931  2.494317e+06
# 131932  3.854071e+06
#
# [131933 rows x 7 columns]

# %% [markdown]
# #### Access variables inside...

# %%
# Access elements using either dot or bracket notation
print df['Pdg'][25]
print df.Pdg[25]
# Out:
# 211
# 211

# %% [markdown]
# #### Loop through events...

# %%
# Loop through 3 first particles and print PDG
for i,particle in df[:3].iterrows():
    print i,particle['Pdg']
# Out:
# 0 211.0
# 1 211.0
# 2 211.0

# %% [markdown]
# #### Describe dataframe...

# %%
df.describe()
# Out:
#                  Pdg             Vx             Vy             Vz  \
# count  131933.000000  131933.000000  131933.000000  131933.000000
# mean      218.057749       0.092554      -0.091217     559.739892
# std        26.954519      15.762305      15.722780       0.004411
# min       211.000000     -88.233200     -89.939384     559.539978
# 25%       211.000000      -9.340580      -9.448129     559.739990
# 50%       211.000000       0.121796      -0.152355     559.739990
# 75%       211.000000       9.527519       9.279242     559.739990
# max       321.000000      87.821411      87.456352     559.739990
#
#                  Px            Py            Pz
# count  1.319330e+05  1.319330e+05  1.319330e+05
# mean   5.558738e+02 -7.038328e+02  3.305260e+06
# std    1.126751e+05  1.128091e+05  1.889557e+06
# min   -1.428772e+06 -1.263632e+06 -4.523402e+05
# 25%   -4.434812e+04 -4.536860e+04  1.678112e+06
# 50%    4.578891e+02 -4.869808e+02  3.278434e+06
# 75%    4.575419e+04  4.420071e+04  4.792502e+06
# max    1.260300e+06  1.758406e+06  7.883688e+06

# %% [markdown]
# #### Apply cuts...

# %%
# Describe cuts for pions with forward momentum 50 times larger than transverse momentum
cut1 = (df.Pdg == 211)
cut2 = (df.Pz/np.sqrt(df.Px**2 + df.Py**2) > 50)
# Combine cuts
cut = cut1 & cut2
# Apply cuts
cutDf = df[cut]
# Print to screen
cutDf
# Out:
#         Pdg         Vx         Vy         Vz            Px            Py  \
# 1       211   2.049445  -2.937980  559.73999 -16944.531250  10193.381836
# 3       211  -3.974789   7.071727  559.73999 -53305.992188  91847.179688
# 9       211 -16.104229  -6.477342  559.73999  -9910.785156  -3662.408447
# 13      211   3.422769  -8.720152  559.73999   3059.918701 -27732.841797
# 131873  211  -5.939250  -9.586168  559.73999 -42574.203125 -65439.988281
# 131874  211   1.737485   9.833409  559.73999   6137.362305  29781.488281
# 131878  211   0.354079  -0.506252  559.73999 -12636.386719 -10065.333008
# 131879  211   7.270066   1.870071  559.73999  -7071.900879  -3636.693115
# 131884  211  -1.520220   1.556599  559.73999  29151.417969 -16124.029297
# 131904  211  -2.735257   9.600623  559.73999 -13496.754883  52276.367188
# 131907  211  -8.257463   8.054507  559.73999 -56335.230469  55364.320312
# 131913  211  -0.577214   3.299363  559.73999  28997.064453   5034.815430
# 131914  211  -0.371697   0.247817  559.73999 -16400.789062 -35415.328125
# 131922  211  -3.490065  -3.333026  559.73999 -19572.109375 -26650.878906
# 131928  211  -0.318634  -3.079620  559.73999  11329.395508  20785.449219
# 131930  211   7.379070   5.660105  559.73999  13772.227539  15242.517578
# 131932  211  -0.232133   2.270126  559.73999  28861.714844  27650.474609
#
#                   Pz
# 1       2.857202e+06
# 3       6.621078e+06
# 9       1.070834e+06
# 13      2.587644e+06
# 22      5.592748e+06
# 26      2.160476e+06
# 30      5.992650e+06
# 33      4.309364e+06
# 39      2.124324e+06
# 50      5.302226e+06
# 54      2.613406e+06
# 55      4.101934e+06
# 58      3.351434e+06
# 68      3.066173e+06
# 71      1.245609e+06
# 73      3.155166e+06
# 74      1.395553e+06
# 81      3.590312e+06
# 82      4.489123e+06
# 83      2.432819e+06
# 87      2.566500e+05
# 97      1.891554e+06
# 103     5.218617e+05
# 107     2.979298e+06
# 110     8.051966e+05
# 112     5.541685e+06
# 114     4.122998e+06
# 115     3.134798e+06
# 117     2.003537e+06
# 123     4.071404e+06
# ...              ...
# 131823  2.771296e+06
# 131828  4.464108e+06
# 131829  2.464892e+06
# 131830  2.548244e+06
# 131831  1.864310e+06
# 131832  5.703456e+06
# 131839  4.669790e+06
# 131841  4.042622e+06
# 131843  5.046020e+06
# 131849  4.845220e+06
# 131857  5.797962e+06
# 131862  5.857769e+06
# 131865  1.256855e+06
# 131866  1.883344e+06
# 131867  5.359623e+06
# 131869  5.992760e+06
# 131870  3.584255e+06
# 131873  4.659564e+06
# 131874  3.097734e+06
# 131878  1.905836e+06
# 131879  1.699070e+06
# 131884  2.733255e+06
# 131904  4.613932e+06
# 131907  4.684140e+06
# 131913  3.617230e+06
# 131914  2.045311e+06
# 131922  3.702776e+06
# 131928  3.047436e+06
# 131930  3.852642e+06
# 131932  3.854071e+06
#
# [40812 rows x 7 columns]

# %% [markdown]
# # Plotting with matplotlib
# There would be a whole book to write about matplotlib, we'll leave the details for some other lesson.
#
# If in the mean time you want to start playing with it, take a look at this:
# https://www.labri.fr/perso/nrougier/teaching/matplotlib/

# %%
fig = plt.figure(figsize=figsize)
n,hist,_ = plt.hist(df['Pz'],100,label='PreCut')
n,hist,_ = plt.hist(cutDf['Pz'],100,label='PostCut')
plt.xlabel('Momentum [eV]')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Widgets
# Why not combining matplotlib with widgets for easier exploration and plot manipulation?
#
# For more info, I've made an example here: https://github.com/sdporzio/codingExamples/blob/master/Jupyter/widgets_3dPlots.ipynb
#
# You can find instructions here:
# https://ipywidgets.readthedocs.io/en/latest/

# %%
from ipywidgets import interact, interactive, fixed, widgets

def plot(Pdg=211,ratio=50):
    fig = plt.figure(figsize=figsize)
    
    # Apply cuts
    cut = (df.Pz/np.sqrt(df.Px**2 + df.Py**2) > ratio)
    cutDf = df[cut]
    n,hist,_ = plt.hist(df[df.Pdg==Pdg]['Pz'],100,label='PreCut')
    n,hist,_ = plt.hist(cutDf[cutDf.Pdg==Pdg]['Pz'],100,label='PostCut')
    plt.xlabel('Momentum [eV]')
    plt.legend()
    plt.grid()
    plt.show()
    
w_Pdg = {'Kaon (321)':321,'Pion (211)':211}
w_Ratio = (0,100,5)

# %%
interact(plot,Pdg=w_Pdg,ratio=w_Ratio)

# %% [markdown]
# #### You can do the same for easier visualization, especially for 3d plots
# The widgets can take care of any variable

# %%
from ipywidgets import interact, interactive, fixed, widgets
from mpl_toolkits.mplot3d import Axes3D
from sklearn import datasets

# Actual data is flow
iris = datasets.load_iris()
data = iris.data
test = iris.target
data1 = data[np.where(test==0)]
data2 = data[np.where(test==1)]
data3 = data[np.where(test==2)]

def look(elevation=10,azimuth=75):
    fig = plt.figure(figsize=figsize)
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(data1[:,0],data1[:,1],data1[:,2],s=20,c='r',label=r'$e^{-}$')
    ax.scatter(data2[:,0],data2[:,1],data2[:,2],s=20,c='b',label=r'$\mu^{-}$')
    ax.scatter(data3[:,0],data3[:,1],data3[:,2],s=20,c='g',label=r'$\pi^{-}$')
    ax.view_init(elev=elevation, azim=azimuth)
    plt.legend()
    plt.show()
    
w_elev = (0,90,5)
w_azim = (0,90,5)

# %%
interact(look, elevation=w_elev, azimuth=w_azim)

# %% [markdown]
# #### Other useful widgets include progress bars
#
# (You may not be able to run this cell, since you'll need to install the LogProgress separately, you can find the module here: https://github.com/alexanderkuk/log-progress)

# %%
from NotebookUtils.ProgressBar import LogProgress as LP

n = int(1e6)
divisor = 47
numbers = []

for i in LP(range(n)):
    if i%divisor == 0:

        numbers.append(i)

# %% [markdown]
# #### Progress bars are also useful with audio warnings

# %%
def Bell(): os.system('afplay /System/Library/Sounds/Ping.aiff')

# Repeating same operation for multiple loops
for i in LP(range(1,6)):
    for j in LP(range(n)):
        if j%i == 0:
            numbers.append(j)
    Bell()

# %% [markdown]
# #### Long processes can be appended with 'Bell' and iterators don't have to be in a loop

# %%
import time

i = LP(range(3))
time.sleep(1); i.next(); Bell()
time.sleep(2); i.next(); Bell()
time.sleep(1); i.next(); Bell()

# %%
# Dividing by zero and making it break
for i in LP(range(1,11)):
    if i==7:
        breakIt = 3/0.
    for j in range(n):
        if j%i == 0:
            numbers.append(j)
# Out:
# ZeroDivisionErrorTraceback (most recent call last)
# <ipython-input-17-f904f533258a> in <module>()
#       2 for i in LP(range(1,11)):
#       3     if i==7:
# ----> 4         breakIt = 3/0.
#       5     for j in range(n):
#       6         if j%i == 0:
#
# ZeroDivisionError: float division by zero
